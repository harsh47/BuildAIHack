# %%
pip install pandas-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly-express
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U scikit-learn scipy matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-autotime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Libraries and Packages

# %%
import pandas as pd

# %% [markdown]
# # Loading Datasets

# %%
foodexp = pd.read_csv('BWAI Challenge 3 Dataset/foodexp.csv')
foodsimple = pd.read_csv('BWAI Challenge 3 Dataset/foodsimple.csv')
orderItemsDonations = pd.read_csv('BWAI Challenge 3 Dataset/orderItemsDonations.csv')
foodfridge = pd.read_csv('BWAI Challenge 3 Dataset/foodfridge.csv')
orderHeaderDonations = pd.read_csv('BWAI Challenge 3 Dataset/orderHeaderDonations.csv')
orderItemsRequests = pd.read_csv('BWAI Challenge 3 Dataset/orderItemsRequests.csv')
foodshelf = pd.read_csv('BWAI Challenge 3 Dataset/foodshelf.csv')
orderHeaderRequests = pd.read_csv('BWAI Challenge 3 Dataset/orderHeaderRequests.csv')

# %%
foodexp['TABLE'] = 'foodexp'

# %%
foodsimple['TABLE'] = 'foodsimple'

# %%
foodfridge['TABLE'] = 'foodfridge'

# %%
foodshelf['TABLE'] = 'foodshelf'

# %% [markdown]
# # Concatation

# %%
food = pd.concat([foodexp, foodsimple, foodfridge, foodshelf])

# %%
food
# Out:
#           TYPE                                   ITEM        PERIOD   DETAILS  \
# 0    BEVERAGES  Juice in cartons, fruit drinks, punch       3 weeks  unopened
# 1    BEVERAGES  Juice in cartons, fruit drinks, punch     7-10 days    opened
# 2    BEVERAGES  Juice in cartons, fruit drinks, punch   8-12 months       NaN
# 3        DIARY                                 Butter    1-3 months       NaN
# 4        DIARY                                 Butter    6-9 months       NaN
# ..         ...                                    ...           ...       ...
# 223     BAKERY                          Pies, pumpkin       2 hours       NaN
# 224     BAKERY                                 Quiche       2 hours       NaN
# 225     BAKERY                    Rolls, yeast, baked      3-4 days       NaN
# 226     BAKERY          Rolls, yeast, partially baked  Package date       NaN
# 227     BAKERY      Rolls, filled, meat or vegetables       2 hours       NaN
#
#           STORAGE      TABLE
# ...

# %%
orderItemsDonations
# Out:
#       OrderId  OrderItemId     ProductType  \
# 0       20051            1           DIARY
# 1       20051            2           DIARY
# 2       20051            3           DIARY
# 3       20051            4           DIARY
# 4       20051            5             SOY
# ...       ...          ...             ...
# 9215    20139           35       SHELLFISH
# 9216    20139           36      SHELF_ITEM
# 9217    20139           37           PESTO
# 9218    20139           38          BAKERY
# 9219    20139           39  PROCESSED_MEAT
#
#                              ProductItem ProductPeriod ProductDetails  \
# 0               Cheese, processed slices    1-2 months            NaN
# 1                         Eggs, in shell     3-5 weeks            NaN
# 2                              Margarine     12 months            NaN
# 3                Milk, plain or flavored        1 week            NaN
# 4                                   Tofu        1 week            NaN
# ...

# %%
orderHeaderDonations
# Out:
#      OrderId  PartnerId  OrderTotal   OrderDate PartnerName  PartnerGeoLat  \
# 0      20051     190050        2000  2021-01-11  FoodieLand      -27.49079
# 1      20052     190050        2000  2021-01-12  FoodieLand      -27.49079
# 2      20053     190050        2000  2021-01-13  FoodieLand      -27.49079
# 3      20054     190050        2000  2021-01-14  FoodieLand      -27.49079
# 4      20055     190050        2000  2021-01-15  FoodieLand      -27.49079
# ..       ...        ...         ...         ...         ...            ...
# 262    20135     190052        2000  2021-04-05  Grocertown      -27.54099
# 263    20136     190052        2000  2021-04-06  Grocertown      -27.54099
# 264    20137     190052        2000  2021-04-07  Grocertown      -27.54099
# 265    20138     190052        2000  2021-04-08  Grocertown      -27.54099
# 266    20139     190052        2000  2021-04-09  Grocertown      -27.54099
#
#      PartnerGeoLon
# 0        153.06799
# 1        153.06799
# ...

# %%
orderItemsRequests
# Out:
#       OrderId  OrderItemId        ProductType  \
# 0       50050            1              DIARY
# 1       50050            2         SHELF_ITEM
# 2       50050            3             BAKERY
# 3       50050            4         SHELF_ITEM
# 4       50050            5             BAKERY
# ...       ...          ...                ...
# 5739    50068            9             BAKING
# 5740    50068           10         VEGETABLES
# 5741    50068           11  PROCESSED_POULTRY
# 5742    50068           12                SOY
# 5743    50068           13     PROCESSED_MEAT
#
#                                 ProductItem ProductPeriod ProductDetails  \
# 0                            Eggs, in shell           NaN  Do not freeze
# 1                                 Tea, bags     18 months       unopened
# 2                           Pies, mincemeat      8 months            NaN
# 3           Marshmallows, marshmallow creme    2-4 months       unopened
# ...

# %%
orderHeaderRequests
# Out:
#      OrderId  CustomerId  OrderTotal   OrderDate   Location    CustomerName  \
# 0      50050       90050         200  2021-01-10  AGA North     Mark Burton
# 1      50051       90050         200  2021-01-20  AGA North     Mark Burton
# 2      50052       90050         200  2021-01-25  AGA North     Mark Burton
# 3      50053       90050         200  2021-01-30  AGA North     Mark Burton
# 4      50054       90050         200  2021-02-06  AGA North     Mark Burton
# ..       ...         ...         ...         ...        ...             ...
# 387    50064       90069         200  2021-03-09  AGA South  Elizabeth Holt
# 388    50065       90069         200  2021-03-13  AGA South  Elizabeth Holt
# 389    50066       90069         200  2021-03-17  AGA South  Elizabeth Holt
# 390    50067       90069         200  2021-03-19  AGA South  Elizabeth Holt
# 391    50068       90069         200  2021-03-24  AGA South  Elizabeth Holt
#
#      CustomerGeoLat  CustomerGeoLon
# ...

# %% [markdown]
# # Top Order Requests by ProductType

# %%
orderItemsRequests.groupby('ProductType').count()['OrderId']
# Out:
# ProductType
# BAKERY                569
# BAKING                235
# BEVERAGES              20
# CONDIMENTS            197
# COOKIES                35
# CRACKERS               34
# DELI_ITEM             261
# DIARY                 483
# DOUGH                  69
# FISH                  127
# FRESH_MEAT             67
# FRESH_POULTRY          76
# FROZEN_ITEM           348
# FRUIT                 358
# PASTA                  23
# PESTO                  30
# PROCESSED_MEAT        206
# PROCESSED_POULTRY     142
# SHELF_ITEM           1469
# SHELLFISH             162
# SMOKEDFISH             53
# SOY                   129
# VEGETABLES            651
# Name: OrderId, dtype: int64

# %%
orderItemsRequests.groupby('ProductItem').count()['OrderId']
# Out:
# ProductItem
# Aerosol can, nondairy topping      16
# Aerosol can, real whipped cream    16
# Apples                             35
# Apricots                           31
# Artichokes, whole                  23
#                                    ..
# Water, bottled                     10
# Whipped, sweetened                 14
# Worcestershire Sauce               21
# Yeast, dry, packets and jars       13
# Yogurt                             17
# Name: OrderId, Length: 300, dtype: int64

# %%
df_merged_donations = orderItemsDonations.merge(orderHeaderDonations,on='OrderId')
df_merged_donations
# Out:
#        OrderId  OrderItemId     ProductType                 ProductItem  \
# 0        20051            1           DIARY    Cheese, processed slices
# 1        20051            1           DIARY    Cheese, processed slices
# 2        20051            1           DIARY    Cheese, processed slices
# 3        20051            2           DIARY              Eggs, in shell
# 4        20051            2           DIARY              Eggs, in shell
# ...        ...          ...             ...                         ...
# 27655    20139           38          BAKERY         Rolls, yeast, baked
# 27656    20139           38          BAKERY         Rolls, yeast, baked
# 27657    20139           39  PROCESSED_MEAT  Lunch meats, after opening
# 27658    20139           39  PROCESSED_MEAT  Lunch meats, after opening
# 27659    20139           39  PROCESSED_MEAT  Lunch meats, after opening
#
#       ProductPeriod ProductDetails ProductStorage  Quantity  PartnerId  \
# ...

# %%
df_merged_requests = orderItemsRequests.merge(orderHeaderRequests,on='OrderId')
df_merged_requests
# Out:
#        OrderId  OrderItemId ProductType  \
# 0        50050            1       DIARY
# 1        50050            1       DIARY
# 2        50050            1       DIARY
# 3        50050            1       DIARY
# 4        50050            1       DIARY
# ...        ...          ...         ...
# 97470    50077           14  SHELF_ITEM
# 97471    50077           15  VEGETABLES
# 97472    50077           16       DIARY
# 97473    50077           17       DIARY
# 97474    50077           18  SHELF_ITEM
#
#                                              ProductItem      ProductPeriod  \
# 0                                         Eggs, in shell                NaN
# 1                                         Eggs, in shell                NaN
# 2                                         Eggs, in shell                NaN
# 3                                         Eggs, in shell                NaN
# 4                                         Eggs, in shell                NaN
# ...

# %% [markdown]
# # merge header requests with item requests on OrderId

# %% [markdown]
# # Delta - Wastage

# %% [markdown]
# # Importing Modules

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.cluster import KMeans
# from sklearn.decomposition import PCA
# from sklearn.metrics.pairwise import cosine_similarity
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# from pandas_profiling import ProfileReport
# from kmodes.kprototypes import KPrototypes
# from tqdm import tqdm

# %% [markdown]
# # Loading Data

# %%
df_merged_donations.head(2)
# Out:
#    OrderId  OrderItemId ProductType               ProductItem ProductPeriod  \
# 0    20051            1       DIARY  Cheese, processed slices    1-2 months
# 1    20051            1       DIARY  Cheese, processed slices    1-2 months
#
#   ProductDetails ProductStorage  Quantity  PartnerId  OrderTotal   OrderDate  \
# 0            NaN   REFRIGERATED       105     190050        2000  2021-01-11
# 1            NaN   REFRIGERATED       105     190051        2000  2021-01-11
#
#   PartnerName  PartnerGeoLat  PartnerGeoLon
# 0  FoodieLand      -27.49079      153.06799
# 1    LoMarket      -27.53899      153.07429

# %%
df_merged_donations.shape
# Out:
# (27660, 14)

# %%
# import module
from geopy.geocoders import Nominatim

# %%
# initialize Nominatim API
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
df_merged_donations['location'] = df_merged_donations['PartnerGeoLat'].apply(str)  +","+ df_merged_donations['PartnerGeoLon'].apply(str)

# %%
import numpy as np

# %%
df_merged_donations['city'] = np.nan

# %%
for i in range(len(df_merged_donations['location'])):
    df_merged_donations['city'][i] = geolocator.reverse(df_merged_donations['location'][i])
    print(df_merged_donations['city'][i])
# Out:
# 17, Edencourt Street, Camp Hill, Brisbane City, Queensland, 4152, Australia
# Mount Gravatt Outlook Reserve, Federation Track, Mount Gravatt, Brisbane City, Queensland, 4122, Australia
# Nathan Ridge Track, Nathan Heights, Nathan, Brisbane City, Queensland, 4111, Australia
# 17, Edencourt Street, Camp Hill, Brisbane City, Queensland, 4152, Australia
# Mount Gravatt Outlook Reserve, Federation Track, Mount Gravatt, Brisbane City, Queensland, 4122, Australia
# Nathan Ridge Track, Nathan Heights, Nathan, Brisbane City, Queensland, 4111, Australia
# 17, Edencourt Street, Camp Hill, Brisbane City, Queensland, 4152, Australia
# Mount Gravatt Outlook Reserve, Federation Track, Mount Gravatt, Brisbane City, Queensland, 4122, Australia
# Nathan Ridge Track, Nathan Heights, Nathan, Brisbane City, Queensland, 4111, Australia
# 17, Edencourt Street, Camp Hill, Brisbane City, Queensland, 4152, Australia
# ...

# %%
df_merged_donations['location']
# Out:
# 0        -27.49079,153.06798999999998
# 1                 -27.53899,153.07429
# 2        -27.54099,153.04838999999998
# 3        -27.49079,153.06798999999998
# 4                 -27.53899,153.07429
#                      ...
# 27655             -27.53899,153.07429
# 27656    -27.54099,153.04838999999998
# 27657    -27.49079,153.06798999999998
# 27658             -27.53899,153.07429
# 27659    -27.54099,153.04838999999998
# Name: location, Length: 27660, dtype: object

# %%
df_merged_donations['address'] = df_merged_donations['location'].raw['address']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_243/2895986057.py in <module>
# ----> 1 df_merged_donations['address'] = df_merged_donations['location'].raw['address']
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'raw'

# %%
df_merged_donations['city'] = df_merged_donations['address'].get('city')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'address'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
-x-x

# %%
drop_col= ['OrderId', 'OrderItemId', 'PartnerId','PartnerGeoLat', 'PartnerGeoLon']

# %%
req_rb_table= rb_table.drop(drop_col,axis=1)

# %%
req_rb_table.head()

# %%
#replacing unknown with np.nan
req_rb_table = req_rb_table.replace({'unknown':np.nan,'unknown_gender':np.nan, 'unknown_age':np.nan, 'None':np.nan })

# %%
req_rb_table= req_rb_table.dropna(thresh=req_rb_table.shape[0]*0.7,how='all',axis=1)

# %%
req_rb_table.shape

# %% [markdown]
# # loading excel data

# %%
df_dummy = pd.read_excel('dummy_data.xlsx', sheet_name='RB_Data_Segmentation')

# %%
df_dummy.shape

# %%
# lower case row values
df_dummy = df_dummy.applymap(lambda s:s.lower() if type(s) == str else s)

# %%
# lower case column names
df_dummy.columns = map(str.lower, df_dummy.columns)

# %%
df_dummy = df_dummy.replace({'unknown':np.nan, 'None':np.nan })

# %%
df_dummy.head()

# %%
df_dummy.shape

# %%
df_dummy= df_dummy.dropna(thresh=df_dummy.shape[0]*0.7,how='all',axis=1)

# %%
req_dummy = df_dummy.drop(['id','manufacturer','brand','product','country','date','gmo','channel','post level text'],axis = 1)

# %%
req_dummy.shape

# %%
final_req_table = pd.merge(req_rb_table,req_dummy,on='review_id')
print(final_req_table.shape)

# %%
# dropping columns where all row values are same
nunique = final_req_table.nunique()
cols_to_drop = nunique[nunique == 1].index
final_req_table = final_req_table.drop(cols_to_drop, axis=1)
print(final_req_table.shape)

# %% [markdown]
# ### Removing unnecessary columns

# %%
final_req_table = final_req_table.drop(['review_id','behaviour_score','positive_score_by_weights','negative_score_by_weights',
                                        'predicted_driver'],axis=1,errors='ignore')#,'predicted_driver_ppp','predicted_driver_ilv'

# %% [markdown]
# ### converting year into string

# %%
final_req_table['year'] = final_req_table['year'].astype(int)
final_req_table['year'] = final_req_table['year'].astype(str)

# %%
# Removing Columns with Only 1 distinct value
final_req_table = final_req_table.drop(['drivers_score','emotions_score','people_score','process_score',
                                        'product_score','intent_score','loyalty_score','values_score'],axis=1)

# %%
final_req_table.shape

# %%
# drop columns where one value is more than 70 % 
final_req_table = final_req_table.loc[:, (final_req_table==0).mean() < .7]
final_req_table.shape

# %%
# dropping emotions
final_req_table = final_req_table.drop(final_req_table.filter(regex='emotions').columns,axis=1)

# %%
# dropping emotional_engagement_quintile
final_req_table = final_req_table.drop(['emotional_engagement_quintile'],axis=1)

# %% [markdown]
# # EDA

# %%
df = final_req_table.copy(deep=True)

# %%
# Creating quintiles leads to the major issue called CURSE OF DIMENTIONALITY
# as there will be many combinations, therefore the model failed to generalize result

# %%
# prof = ProfileReport(df)
# prof.to_file(output_file='output.html')




# from pandas_profiling import ProfileReport
# #We only use the first 10000 data points
# prof = ProfileReport(df.sample(n=10000))
# prof.to_file(output_file='output.html')



# pandas_profiling.version.__version__



profile = ProfileReport(df, minimal=True)
profile.to_file(output_file="output_min.html")

# %% [markdown]
# # product
# - high cardinality

# %%
from collections import Counter
def cumulatively_categorise(column,threshold=0.75,return_categories_list=True):
  #Find the threshold value using the percentage and number of instances in the column
  threshold_value=int(threshold*len(column))
  #Initialise an empty list for our new minimised categories
  categories_list=[]
  #Initialise a variable to calculate the sum of frequencies
  s=0
  #Create a counter dictionary of the form unique_value: frequency
  counts=Counter(column)

  #Loop through the category name and its corresponding frequency after sorting the categories by descending order of frequency
  for i,j in counts.most_common():
    #Add the frequency to the global sum
    s+=dict(counts)[i]
    #Append the category name to the list
    categories_list.append(i)
    #Check if the global sum has reached the threshold value, if so break the loop
    if s>=threshold_value:
      break
  #Append the category Other to the list
  categories_list.append('Other')

  #Replace all instances not in our new categories by Other  
  new_column=column.apply(lambda x: x if x in categories_list else 'Other')

  #Return transformed column and unique values if return_categories=True
  if(return_categories_list):
    return new_column,categories_list
  #Return only the transformed column if return_categories=False
  else:
    return new_column

# %%
#Call the function with a default threshold of 75%
transformed_column,new_category_list=cumulatively_categorise(df['product'], threshold = 0.5, return_categories_list=True)

# %%
df['product'].value_counts().head()

# %%
new_category_list

# %%
df['product']= transformed_column

# %%
df['product'].unique()

# %% [markdown]
# # brand
# - high cardinality

# %%
#Call the function with a default threshold of 75%
transformed_column,new_category_list=cumulatively_categorise(df['brand'],threshold=0.7,return_categories_list=True)

# %%
df['brand'].value_counts()

# %%
new_category_list

# %%
df['brand']= transformed_column

# %% [markdown]
# # subbrand
# - high cardinality

# %%
#Call the function with a default threshold of 75%
transformed_column,new_category_list=cumulatively_categorise(df['subbrand'],threshold=0.5,return_categories_list=True)

# %%
df['subbrand'].value_counts()

# %%
new_category_list

# %%
df['subbrand']= transformed_column

# %% [markdown]
# # source
# - high cardinality

# %%
#Call the function with a default threshold of 75%
transformed_column,new_category_list=cumulatively_categorise(df['source'],threshold=0.95,return_categories_list=True)

# %%
new_category_list

# %%
df['source'].value_counts().head()

# %%
df['source']= transformed_column

# %% [markdown]
# ## drop source type -- very baised column

# %%
df = df.drop(['source type'],axis=1)

# %%
# convert zeros to null

# %%
df = df.replace({0:np.nan, 0.00001:np.nan})

# %%
df.shape

# %%
# delete columns having 50% missing values 
df = df.drop(['drivers_waiting_time_score','drivers_value_for_money_score'],axis=1,errors='ignore')

# %% [markdown]
# # handling missing values

# %%
df['rating'] = df['rating'].replace({1.0:'one', 2.0:'two', 3.0:'three', 4.0:'four', 5.0:'five'})

# %%
df = df.reset_index()
df = df.drop(['index'],axis=1,errors='ignore')

# %%
df1 = df.select_dtypes(include ='float64')
df2 = df.select_dtypes(exclude ='float64')

# %%
# categorical
for column in df2.columns:
    df2[column].fillna(df2[column].mode()[0], inplace=True)

# %%
# numeric
df1 = df1.fillna(df1.mean())

# %% [markdown]
# # concat numeric and categoric dataframes

# %%
df = pd.concat([df1,df2], axis=1)

# %%
# dropping milk source (highly biased)

# %%
df['milk source'].value_counts()

# %%
df = df.drop(columns = ['milk source'])

# %% [markdown]
# # gender

# %%
df.gender.value_counts()

# %%
# dropping this gender column and creating new gender column have random male and female values

# %%
df = df.drop(columns = ['gender'])

# %%
gender_list = ['male', 'female']

df["gender"] = np.random.choice(gender_list, size=len(df))

# %% [markdown]
# # final dataframe

# %%
df.head(2)

# %%
# dropping unnecessary columns

# %%
df = df.drop(columns = ['year', 'subbrand', 'form'])

# %% [markdown]
# # standardization

# %%
df1 = df.select_dtypes(include ='float64')
df2 = df.select_dtypes(exclude ='float64')

# %%
col = df1.columns

# %%
scale = StandardScaler()
df1 = scale.fit_transform(df1)

# %%
df1 = pd.DataFrame(df1, columns= col)
